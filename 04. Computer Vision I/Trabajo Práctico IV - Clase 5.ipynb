# %% [markdown]
# ## Computer Vision I
# ### Trabajo Práctico IV

# %%
import cv2 as cv
import numpy as np
import os
from skimage.feature import local_binary_pattern
import matplotlib.pyplot as plt

# %%
img_list = []
lbp_list = []
folder = 'Images/LBP/one/'
radius = 1
n_points = 8 * radius
for filename in os.listdir(folder):
    img = cv.imread(os.path.join(folder, filename))
    gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
    lbp = local_binary_pattern(gray, n_points, radius, method='default')
    img_list.append(gray)
    lbp_list.append(lbp)

    # the histogram of the data
fig, (ax_img, ax_hist, ax_text) = plt.subplots(nrows=3, ncols=3, figsize=(18, 12))
plt.gray()
i=0
j=0
m=0
for ax in ax_img:
    ax.imshow(img_list[i])
    i = i+1
for ax in ax_hist:
    ax.set_ylim([0, 0.05])
    n, bins, patches = ax.hist(lbp_list[j].ravel(), bins=20, density=True)
    cm = plt.cm.RdYlBu_r
    for i, p in enumerate(patches):
        plt.setp(p, 'facecolor', cm(i/20))
    j = j+1
for ax in ax_text:
    ax.imshow(lbp_list[m])
    m = m+1
plt.show()

# %%
img_list = []
lbp_list = []
folder = 'Images/LBP/two/'
radius = 1
n_points = 8 * radius
for filename in os.listdir(folder):
    img = cv.imread(os.path.join(folder, filename))
    gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
    lbp = local_binary_pattern(gray, n_points, radius, method='default')
    img_list.append(gray)
    lbp_list.append(lbp)

    # the histogram of the data
fig, (ax_img, ax_hist, ax_text) = plt.subplots(nrows=3, ncols=2, figsize=(18, 12))
plt.gray()
i=0
j=0
m=0
for ax in ax_img:
    ax.imshow(img_list[i])
    i = i+1
for ax in ax_hist:
    ax.set_ylim([0, 0.02])
    n, bins, patches = ax.hist(lbp_list[j].ravel(), bins=20, density=True)
    cm = plt.cm.RdYlBu_r
    for i, p in enumerate(patches):
        plt.setp(p, 'facecolor', cm(i/20))
    j = j+1
for ax in ax_text:
    ax.imshow(lbp_list[m])
    m = m+1
plt.show()

# %%
img_list = []
lbp_list = []
folder = 'Images/LBP/three/'
radius = 1
n_points = 8 * radius
for filename in os.listdir(folder):
    img = cv.imread(os.path.join(folder, filename))
    gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
    lbp = local_binary_pattern(gray, n_points, radius, method='default')
    img_list.append(gray)
    lbp_list.append(lbp)

    # the histogram of the data
fig, (ax_img, ax_hist, ax_text) = plt.subplots(nrows=3, ncols=2, figsize=(18, 12))
plt.gray()
i=0
j=0
m=0
for ax in ax_img:
    ax.imshow(img_list[i])
    i = i+1
for ax in ax_hist:
    ax.set_ylim([0, 0.02])
    n, bins, patches = ax.hist(lbp_list[j].ravel(), bins=20, density=True)
    cm = plt.cm.RdYlBu_r
    for i, p in enumerate(patches):
        plt.setp(p, 'facecolor', cm(i/20))
    j = j+1
for ax in ax_text:
    ax.imshow(lbp_list[m])
    m = m+1
plt.show()

# %%
img_list = []
lbp_list = []
folder = 'Images/LBP/four/'
radius = 1
n_points = 8 * radius
for filename in os.listdir(folder):
    img = cv.imread(os.path.join(folder, filename))
    gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
    lbp = local_binary_pattern(gray, n_points, radius, method='default')
    img_list.append(gray)
    lbp_list.append(lbp)

    # the histogram of the data
fig, (ax_img, ax_hist, ax_text) = plt.subplots(nrows=3, ncols=6, figsize=(27, 18))
plt.gray()
i=0
j=0
m=0
for ax in ax_img:
    ax.imshow(img_list[i])
    i = i+1
for ax in ax_hist:
    ax.set_ylim([0, 0.025])
    n, bins, patches = ax.hist(lbp_list[j].ravel(), bins=20, density=True)
    cm = plt.cm.RdYlBu_r
    for i, p in enumerate(patches):
        plt.setp(p, 'facecolor', cm(i/20))
    j = j+1
for ax in ax_text:
    ax.imshow(lbp_list[m])
    m = m+1
plt.show()
